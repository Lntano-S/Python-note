# %%
# DayDayUpv1.py
dayup = pow((1.0+0.001),365)
daydown = pow((1.0-0.001),365)
print("向上：{:.2f}，悠闲：{:.2f}.".format(dayup,daydown))
# Out:
# 向上：1.44，悠闲：0.69.

# %%
#避免使用直接量，多定义变量  
#实例3.4

start = 1.0
up = 0.001
down = 0.001
days = 365
for i in range(1,366):
    if i%7 in [6,0]:
        start = start*(1-down)
    else:
        start = start*(1+up)
print("努力5天，悠闲2天：{:.2f}.".format(start))
# Out:
# 努力5天，悠闲2天：1.17.

# %%
#实例3.4
