# %%
import pandas as pd
data_dict = {
    "zhangsan" : 96.0, 
    "wangwu" : 97.0
}

s1 = pd.Series(data_dict, name="作业1")
print(s1)
# Out:
# zhangsan    96.0
# wangwu      97.0
# Name: 作业1, dtype: float64
