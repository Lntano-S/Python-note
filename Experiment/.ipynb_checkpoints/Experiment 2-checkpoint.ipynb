# %%
x = 5
y = 2
x + y
# Out:
# 7

# %%
x = 5
y = 2
x - y
# Out:
# 3

# %%
x = 5
y = 2
x * y
# Out:
# 10

# %%
x = 5
y = 2
x / y
# Out:
# 2.5

# %%
x = 5
y = 2
x // y
# Out:
# 2

# %%
x = 5
y = 2
x % y
# Out:
# 1

# %%
x = 5
y = 2
x ** y
# Out:
# 25

# %%
x = 5
y = 2
x > y
# Out:
# True

# %%
x = 5
y = 2
x == y
# Out:
# False

# %%
x = 5
y = 2
x and y
# Out:
# 2

# %%
x = 5
y = 2
x or y
# Out:
# 5

# %%
x = 5
y = 2
not x
# Out:
# False

# %%
#题目2
score1 = int(input("请输入成绩1："))
score2 = int(input("请输入成绩2："))
score3 = int(input("请输入成绩3："))
sum = score1 + score2 + score3
avg = sum/3
print(sum, avg)
# Out:
# 请输入成绩1： 85
# 请输入成绩2： 88
# 请输入成绩3： 100
# 273 91.0

# %%
#题目3
n = 921
a = n // 100
b = (n // 10) % 10
c = n % 10
d = c*100 + b*10 + a
print(d)
# Out:
# 129

# %%
#题目4 (从键盘上输入要用input)
a = eval(input("请输入a的值:"))
b = eval(input("请输入b的值:"))
print(a + b,a - b,a * b,a / b)
# Out:
# 请输入a的值: 4
# 请输入b的值: 2
# 6 2 8 2.0

# %%
#题目5
import math as m
pi = m.pi
r = eval(input("请输入r的值:"))
h = eval(input("请输入h的值:"))
V = (pi * pow(r, 2) * h) / 3
print(round(V, 2))
# Out:
# 请输入r的值: 4
# 请输入h的值: 6
# 100.53

# %%
#题目6.1
a = "www.moe.gov.cn"
print(a[0])
print(a[0:3])
print(a[-3:]) #去掉右边边界来取到末尾字符
print(len(a))
# Out:
# w
# www
# .cn
# 14
