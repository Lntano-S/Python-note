# %% [markdown]
# ## Python 基本语法元素复习资料
#
# ### 1. 基本语法元素
#
# #### 1.1 注释

# %%
# 这是单行注释

"""
这是多行注释
可以写很多行
"""

'''
这也是多行注释
'''

# %% [markdown]
# #### 1.2 缩进（重要！）

# %%
# Python 用缩进表示代码块，通常用 4 个空格
if True:
    print("这行有缩进")
    print("这行也有缩进")
print("这行没有缩进")

# %% [markdown]
# #### 1.3 变量命名规则
# - 只能包含字母、数字、下划线
# - 不能以数字开头
# - 区分大小写
# - 不能使用关键字

# %%
# 正确的变量名
name = "张三"
age_1 = 20
_private = "私有"

# 错误的变量名
# 2name = "错误"  # 不能以数字开头
# for = "错误"    # for 是关键字

# %% [markdown]
# #### 1.4 Python 关键字（常见的）

# %%
and, or, not, if, else, elif, for, while, def, class, 
import, from, as, try, except, finally, with, in, is, 
True, False, None, return, break, continue, pass

# %% [markdown]
# ---
#
# ### 2. 基本数据类型
#
# #### 2.1 数字类型
#
# **整数 (int)**

# %%
a = 10
b = -5
c = 0
print(type(a))  # <class 'int'>

# %% [markdown]
# **浮点数 (float)**

# %%
x = 3.14
y = -2.5
z = 1.0
print(type(x))  # <class 'float'>

# %% [markdown]
# **复数 (complex)**

# %%
c1 = 3 + 4j
c2 = complex(3, 4)
print(c1.real)  # 3.0
print(c1.imag)  # 4.0

# %% [markdown]
# #### 2.2 字符串 (str)
#
# **创建字符串**

# %%
s1 = "Hello"
s2 = 'World'
s3 = """多行
字符串"""

# %% [markdown]
# **字符串索引和切片（重要！）**

# %%
s = "Python"
print(s[0])     # P (第一个字符)
print(s[-1])    # n (最后一个字符)
print(s[0:3])   # Pyt (索引0到2)
print(s[2:])    # thon (索引2到末尾)
print(s[:4])    # Pyth (开头到索引3)
print(s[-3:])   # hon (最后3个字符)

# %% [markdown]
# **常用字符串方法**

# %%
s = "  Hello World  "
print(s.upper())        # 转大写
print(s.lower())        # 转小写
print(s.strip())        # 去除两端空格
print(s.replace("o", "0"))  # 替换
print(s.split())        # 分割成列表
print(len(s))           # 字符串长度

# %% [markdown]
# #### 2.3 布尔值 (bool)

# %%
flag1 = True
flag2 = False
print(type(flag1))  # <class 'bool'>

# 布尔运算
print(True and False)   # False
print(True or False)    # True
print(not True)         # False

# %% [markdown]
# #### 2.4 空值 (NoneType)

# %%
result = None
print(type(result))  # <class 'NoneType'>

# %% [markdown]
# ---
#
# ### 3. 集合数据类型
#
# #### 3.1 列表 (list) - 可变、有序

# %%
# 创建列表
lst = [1, 2, 3, "hello", True]
empty_list = []

# 访问元素
print(lst[0])    # 1
print(lst[-1])   # True

# 常用方法
lst.append(4)         # 添加元素
lst.insert(1, "new")  # 在索引1插入
lst.remove(2)         # 删除值为2的元素
lst.pop()             # 删除最后一个元素
print(len(lst))       # 列表长度

# %% [markdown]
# #### 3.2 元组 (tuple) - 不可变、有序

# %%
# 创建元组
tup = (1, 2, 3, "hello")
single_tup = (1,)  # 单元素元组需要逗号
empty_tup = ()

# 访问元素（和列表相同）
print(tup[0])    # 1
print(tup[-1])   # hello

# 元组不能修改，但可以进行以下操作
print(len(tup))  # 长度
print(tup.count(1))  # 统计元素出现次数

# %% [markdown]
# #### 3.3 字典 (dict) - 可变、无序（键值对）

# %%
# 创建字典
dic = {"name": "张三", "age": 20, "city": "北京"}
empty_dict = {}

# 访问和修改
print(dic["name"])      # 张三
dic["age"] = 21         # 修改值
dic["gender"] = "男"    # 添加新键值对

# 常用方法
print(dic.keys())       # 所有键
print(dic.values())     # 所有值
print(dic.items())      # 所有键值对
print(len(dic))         # 字典长度

# %% [markdown]
# #### 3.4 集合 (set) - 可变、无序、不重复

# %%
# 创建集合
s1 = {1, 2, 3, 3}  # 重复元素会被去除
s2 = set([1, 2, 3])
empty_set = set()  # 注意：{}是空字典

print(s1)  # {1, 2, 3}

# 常用操作
s1.add(4)      # 添加元素
s1.remove(2)   # 删除元素
print(len(s1)) # 集合长度

# %% [markdown]
# ---
#
# ### 4. 输入输出
#
# #### 4.1 输出 - print()

# %%
print("Hello")
print("Hello", "World")          # 多个值
print("Hello", end="")           # 不换行
print("Hello", "World", sep="-") # 自定义分隔符

# %% [markdown]
# #### 4.2 输入 - input()

# %%
name = input("请输入姓名：")     # 返回字符串
age = int(input("请输入年龄："))  # 转换为整数

# 一次输入多个值
a, b = map(int, input().split())  # 用空格分隔的两个整数

# %% [markdown]
# ---
#
# ### 5. 运算符
#
# #### 5.1 算术运算符

# %%
print(5 + 2)   # 7   加法
print(5 - 2)   # 3   减法
print(5 * 2)   # 10  乘法
print(5 / 2)   # 2.5 除法（浮点）
print(5 // 2)  # 2   整除
print(5 % 2)   # 1   取模
print(5 ** 2)  # 25  幂运算

# %% [markdown]
# #### 5.2 比较运算符

# %%
print(5 > 2)   # True
print(5 < 2)   # False
print(5 == 2)  # False 等于
print(5 != 2)  # True  不等于
print(5 >= 2)  # True  大于等于
print(5 <= 2)  # False 小于等于

# %% [markdown]
# #### 5.3 逻辑运算符

# %%
print(True and False)  # False
print(True or False)   # True
print(not True)        # False

# %% [markdown]
# ---
#
# ### 6. 类型转换

# %%
# 转换为整数
int("123")     # 123
int(3.14)      # 3
int(True)      # 1

# 转换为浮点数
float("3.14")  # 3.14
float(3)       # 3.0

# 转换为字符串
str(123)       # "123"
str(3.14)      # "3.14"

# 转换为布尔值
bool(1)        # True
bool(0)        # False
bool("")       # False
bool("hello")  # True

# 转换为列表
list("abc")    # ['a', 'b', 'c']
list((1,2,3))  # [1, 2, 3]

# %% [markdown]
# ---
#
# ### 7. 常用内置函数

# %%
# 数学函数
abs(-5)        # 5   绝对值
max(1,2,3)     # 3   最大值
min(1,2,3)     # 1   最小值
sum([1,2,3])   # 6   求和
round(3.14, 1) # 3.1 四舍五入

# 类型判断
type(123)      # <class 'int'>
isinstance(123, int)  # True

# 长度
len("hello")   # 5
len([1,2,3])   # 3

# %% [markdown]
# ---
#
# ### 8. 字符串格式化

# %%
name = "张三"
age = 20

# f-string（推荐）
print(f"我是{name}，今年{age}岁")

# format方法
print("我是{}，今年{}岁".format(name, age))

# %格式化
print("我是%s，今年%d岁" % (name, age))

# %% [markdown]
# ---
#
# ## 考试重点提醒：
#
# 1. **缩进**：Python 的代码块用缩进表示，不是大括号
# 2. **字符串切片**：记住索引规则，负数索引从-1开始
# 3. **数据类型**：熟记 int, float, str, bool, list, tuple, dict, set
# 4. **input()返回字符串**：需要int()或float()转换
# 5. **可变vs不可变**：列表、字典、集合可变；字符串、元组不可变
# 6. **运算符优先级**：** > */% > +- > 比较 > not > and > or
#
# **最后15分钟建议**：快速过一遍数据类型的创建方法和常用操作！
#
# 祝您考试顺利！🎯
